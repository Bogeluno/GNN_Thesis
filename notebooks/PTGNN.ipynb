# %%
import pandas as pd
import networkx as nx
import numpy as np
import glob
from tqdm import tqdm
import pickle
from scipy import sparse
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from datetime import date, timedelta
import torch.optim as optim
import torch.nn as nn
from torch_geometric.nn import GCNConv, MessagePassing, Linear
from torch_geometric import utils, data
from torch_geometric.loader import DataLoader
from sklearn.metrics import r2_score
pd.set_option('mode.chained_assignment',None)

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class NNNConv(MessagePassing):
    def __init__(self, in_channels, out_channels):
        super().__init__(aggr='add') #  "Max" aggregation.
        self.mlp = nn.Sequential(nn.Linear(2 * in_channels, out_channels),
                       nn.ReLU(),
                       nn.Linear(out_channels, out_channels))

    def forward(self, x, edge_index, edge_weight):
        return self.propagate(edge_index, x=x, edge_weight=edge_weight)

    def message(self, x_i, x_j, edge_weight):
        tmp = torch.cat([x_i, x_j], dim=1) 
        return edge_weight.view(-1, 1) * self.mlp(tmp)

# %%
zones = [int(z[3:]) for z in pd.read_csv('data/processed/SimpleNNData.csv', index_col=0).filter(regex = 'lz').columns]
def make_PTG(graph, zones):
    attr, adj = graph

    # Filter out 
    if (attr.time_to_reservation.values[-1] >= 48) or ~attr.next_customer[-1]:
        return None
    
    if attr.leave_zone[-1] not in zones:
        return None

    # Slice
    _, labels = sparse.csgraph.connected_components(csgraph=adj, directed=False, return_labels=True)
    newl = labels[-1]
    indices = labels == newl   

    attr = attr[indices]
    adj = adj[indices,:].tocsc()[:,indices].tocsr()

    # Time variables
    attr['weekend'] = attr.time.dt.weekday//5

    def circle_transform(col, max_val=86400):
        tot_sec = ((col - col.dt.normalize()) / pd.Timedelta('1 second')).astype(int)
        cos_val = np.cos(2*np.pi*tot_sec/max_val)
        sin_val = np.sin(2*np.pi*tot_sec/max_val)
        return cos_val, sin_val

    attr['Time_Cos'], attr['Time_Sin'] = [x.values for x in circle_transform(attr.time)]

    # drop
    attr.drop(columns=['park_location_lat', 'park_location_long', 'leave_location_lat', 'leave_location_long', 'park_fuel', 'park_zone', 'moved', 'movedTF', 'time', 'prev_customer', 'next_customer'], inplace = True)

    # One hot encoding
    attr['leave_zone'] = pd.Categorical(attr['leave_zone'], categories=zones)
    attr = pd.get_dummies(attr, columns = ['leave_zone'], prefix='lz')

    attr['engine']= pd.Categorical(attr['engine'], categories=['118I', 'I3', 'COOPER', 'X1'])
    attr = pd.get_dummies(attr, columns = ['engine'], prefix='eng')

    # Normalize fuel and dist 
    attr['leave_fuel'] = attr['leave_fuel']/100
    #df['dist_to_station'] = df['dist_to_station']/5320

    # Get edges
    edge_index, edge_weight = utils.convert.from_scipy_sparse_matrix(adj)

    # Make pytorch data type
    d = data.Data(x = torch.tensor(attr.drop(columns = ['time_to_reservation']).to_numpy(dtype = 'float')).float(), edge_index=edge_index, edge_attr=edge_weight.float(), y = torch.tensor(attr.time_to_reservation.values).float())

    return d

# %%
sdate = date(2019, 9, 15)   # start date
edate = date(2019, 9, 17)   # end date
delta = edate - sdate       # as timedelta
files = ['data/processed/Graphs/'+(sdate + timedelta(days=i)).strftime("%Y%m%d")+'.pickle' for i in range(delta.days + 1)]

dataset = []

with open(files[0], 'rb') as f:
    graph_collection = pickle.load(f)

for g in graph_collection.values():
    res = make_PTG(g,zones)
    if res:
        dataset.append(res)

train_val_size = int(0.8 * len(dataset))
val_test_size = len(dataset)-train_val_size
train_val_data, test_data = torch.utils.data.random_split(dataset, [train_val_size, val_test_size])
train_size = train_val_size-val_test_size
train_data, val_data = torch.utils.data.random_split(train_val_data, [train_size, val_test_size])
del train_val_data

for file in tqdm(files[1:]):
    dataset = []
    with open(file, 'rb') as f:
        graph_collection = pickle.load(f)

    for g in graph_collection.values():
        res = make_PTG(g,zones)
        if res:
            dataset.append(res)

    train_val_size = int(0.8 * len(dataset))
    val_test_size = len(dataset)-train_val_size
    train_val_data_tmp, test_data_tmp = torch.utils.data.random_split(dataset, [train_val_size, val_test_size])
    train_size = train_val_size-val_test_size
    train_data_tmp, val_data_tmp = torch.utils.data.random_split(train_val_data_tmp, [train_size, val_test_size])

    train_data = torch.utils.data.ConcatDataset([train_data,train_data_tmp])
    val_data = torch.utils.data.ConcatDataset([val_data,val_data_tmp])
    test_data = torch.utils.data.ConcatDataset([test_data,test_data_tmp])

#del train_val_data_tmp, test_data_tmp, train_data_tmp, val_data_tmp, dataset
# Out:
# 100%|██████████| 2/2 [00:54<00:00, 27.38s/it]

# %%
train_val_size = int(0.8 * len(dataset))
val_test_size = len(dataset)-train_val_size
train_val_data, test_data = torch.utils.data.random_split(dataset, [train_val_size, val_test_size])
train_size = train_val_size-val_test_size
train_data, val_data = torch.utils.data.random_split(train_val_data, [train_size, val_test_size])
del dataset

# %%
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=1, shuffle=False)

# %%
class GCN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = NNNConv(264, 64)
        self.lin = Linear(64,1)

    def forward(self, data):
        x, edge_index, edge_weight = data.x, data.edge_index, data.edge_attr

        x = self.conv1(x, edge_index, edge_weight)
        x = F.relu(x)
        #x = F.dropout(x, p = 0.2, training=self.training)
        x = self.lin(x)

        return x.squeeze()

GNN = GCN().to(device)
print(GNN, sum(p.numel() for p in GNN.parameters()))
# Out:
# GCN(
#   (conv1): NNNConv(
#     (mlp): Sequential(
#       (0): Linear(in_features=528, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (lin): Linear(64, 1, bias=True)
# ) 38081

# %%
optimizer = optim.Adam(GNN.parameters(), lr=0.03, weight_decay = 0.0001) #Chaged to Adam and learning + regulariztion rate set
criterion = nn.MSELoss(reduction = 'mean')

# %%
GNN.state_dict()
# Out:
# OrderedDict([('conv1.mlp.0.weight',
#               tensor([[ 0.0207, -0.0294, -0.0187,  ...,  0.0049,  0.0378, -0.0235],
#                       [-0.0078, -0.0161, -0.0092,  ..., -0.0219, -0.0432, -0.0143],
#                       [-0.0131,  0.0054, -0.0292,  ...,  0.0306,  0.0294,  0.0428],
#                       ...,
#                       [-0.0030,  0.0230, -0.0241,  ...,  0.0142, -0.0045, -0.0234],
#                       [-0.0102, -0.0149,  0.0235,  ...,  0.0073, -0.0253, -0.0353],
#                       [ 0.0205, -0.0337, -0.0312,  ...,  0.0382,  0.0267, -0.0306]])),
#              ('conv1.mlp.0.bias',
#               tensor([-0.0052,  0.0372, -0.0141, -0.0100,  0.0143, -0.0321,  0.0096,  0.0282,
#                        0.0086, -0.0050,  0.0208, -0.0098,  0.0402, -0.0398,  0.0303, -0.0351,
#                       -0.0363,  0.0397,  0.0168, -0.0134,  0.0371, -0.0336, -0.0087, -0.0318,
#                       -0.0031, -0.0183,  0.0081,  0.0331,  0.0264,  0.0333, -0.0200,  0.0218,
#                        0.0085,  0.0027,  0.0195, -0.0237,  0.0162, -0.0188,  0.0385, -0.0021,
#                       -0.0343,  0.0179,  0.0031,  0.0248, -0.0054,  0.0318,  0.0144, -0.0292,
#                        0.0236,  0.0306, -0.0118, -0.0259,  0.0294,  0.0327, -0.0260,  0.0228,
#                        0.0164, -0.0170,  0.0170, -0.0221,  0.0329, -0.0226,  0.0257,  0.0011])),
#              ('conv1.mlp.2.weight',
#               tensor([[-0.0461, -0.0889, -0.0786,  ...,  0.1230,  0.0909, -0.0863],
#                       [ 0.0551,  0.0842,  0.0770,  ...,  0.0173,  0.0619, -0.0261],
#                       [ 0.0991,  0.0867, -0.0042,  ..., -0.0545, -0.0669, -0.1019],
#                       ...,
#                       [ 0.0420,  0.1166, -0.0155,  ..., -0.0386, -0.1081, -0.0873],
#                       [ 0.0651, -0.0497,  0.0944,  ..., -0.0565, -0.1124,  0.0414],
#                       [-0.0671, -0.0005,  0.0235,  ..., -0.0730, -0.0830,  0.0269]])),
#              ('conv1.mlp.2.bias',
#               tensor([-0.0372,  0.0841, -0.1090, -0.0615,  0.0732,  0.1142,  0.0043,  0.1042,
#                       -0.0110, -0.1029, -0.0675,  0.0959,  0.1001, -0.1056,  0.0864,  0.0362,
#                       -0.1132,  0.1048, -0.0286,  0.0153,  0.0246,  0.0526,  0.0804,  0.0187,
#                        0.0434,  0.0500,  0.0673,  0.0276, -0.0820,  0.0657,  0.0355,  0.0279,
#                       -0.0149,  0.0741,  0.0161, -0.1215,  0.0777, -0.0336,  0.0786,  0.0779,
#                       -0.0084,  0.1139,  0.0025, -0.0117, -0.0008,  0.0320, -0.0073,  0.0380,
#                       -0.0696,  0.0567, -0.0898, -0.0776, -0.0198, -0.0160, -0.0472, -0.0831,
#                       -0.0096,  0.0580, -0.0026,  0.0762,  0.0711,  0.1108,  0.0083, -0.0160])),
#              ('lin.weight',
#               tensor([[ 0.0102,  0.0296,  0.0470, -0.0514, -0.0719, -0.0443,  0.0097,  0.1163,
#                         0.0169,  0.1179, -0.0569, -0.0704,  0.0619,  0.0263,  0.1114,  0.0196,
#                         0.0122, -0.1033, -0.0773,  0.0783,  0.0158, -0.0217, -0.0761, -0.1150,
#                         0.0609,  0.0054,  0.0267, -0.0637, -0.1044,  0.1176,  0.0341,  0.1127,
#                         0.0371, -0.0238,  0.1183, -0.0792,  0.1229,  0.1113,  0.1024, -0.0585,
#                        -0.0728,  0.0901, -0.0807, -0.0269, -0.0629, -0.1192,  0.0882, -0.0241,
#                         0.0273,  0.0648, -0.1005,  0.1070, -0.0459, -0.0494,  0.1063, -0.0854,
#                         0.0881, -0.0520, -0.0634, -0.1144, -0.0891, -0.0535,  0.0388, -0.1218]])),
#              ('lin.bias', tensor([0.0841]))])

# %%
# Set number of epochs
num_epochs = 3

# Set up lists for loss/R2
train_r2, train_loss = [], []
valid_r2, valid_loss = [], []
cur_loss = 0
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    ### Train
    cur_loss_train = []
    GNN.train()
    for batch in train_loader:
        optimizer.zero_grad()
        out = GNN(batch)
        batch_loss = criterion(out[batch.ptr[1:]-1],batch.y[batch.ptr[1:]-1])
        batch_loss.backward()
        optimizer.step()

        cur_loss_train.append(batch_loss.item())
    
    train_losses.append(np.mean(cur_loss_train))

    ### Evaluate training
    GNN.eval()
    train_preds, train_targs = [], []
    for batch in train_loader:
        preds = GNN(batch)
        train_targs += list(batch.y.numpy()[batch.ptr[1:]-1])
        train_preds += list(preds.detach().numpy()[batch.ptr[1:]-1])


    ### Evaluate validation
    val_preds, val_targs = [], []
    cur_loss_val = []
    for batch in val_loader:
        preds = GNN(batch)[batch.ptr[1:]-1]
        y_val = batch.y[batch.ptr[1:]-1]
        val_targs += list(y_val.numpy())
        val_preds += list(preds.detach().numpy())
        cur_loss_val.append(criterion(preds, y_val).item())

    val_losses.append(np.mean(cur_loss_val))


    train_r2_cur = r2_score(train_targs, train_preds)
    valid_r2_cur = r2_score(val_targs, val_preds)
    
    train_r2.append(train_r2_cur)
    valid_r2.append(valid_r2_cur)

    print("Epoch %2i: Train Loss %f , Valid Loss %f ,Train R2 %f, Valid R2 %f" % (
                epoch+1, train_losses[-1], val_losses[-1],train_r2_cur, valid_r2_cur))
# Out:
# Epoch  1: Train Loss 22.369354 , Valid Loss 29.154264 ,Train R2 0.180848, Valid R2 0.072168
# Epoch  2: Train Loss 18.299884 , Valid Loss 28.489233 ,Train R2 0.348515, Valid R2 0.101050
# Epoch  3: Train Loss 15.703176 , Valid Loss 28.154302 ,Train R2 0.340748, Valid R2 0.106605

# %%
def haversine_start(df, car1, car2, max_dist = 1500):
    def _edge_weight(x, max_dist):
        return max((max_dist-x)/max_dist,0)
    dfc1 = df[df.car == car1]
    dfc2 = df[df.car == car2]

    point1 = dfc1[['leave_location_lat','leave_location_long']].values[0]
    point2 = dfc2[['leave_location_lat','leave_location_long']].values[0]
    #return point1

    # convert decimal degrees to radians
    lat1, lon1 = map(np.radians, point1)
    lat2, lon2 = map(np.radians, point2)

    # Deltas
    delta_lon = lon2 - lon1 
    delta_lat = lat2 - lat1 
    
    # haversine formula 
    a = np.sin(delta_lat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(delta_lon/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) 
    r = 6371000 # Radius of earth in m
    return _edge_weight(c * r, max_dist)

def haversine_add(current_locs, to_add, max_dist = 1500):
    def _edge_weight(x, max_dist):
        return max((max_dist-x)/max_dist,0)
    def _haversine(point1, lat2, lon2):
        
         # convert decimal degrees to radians
        lat1, lon1 = map(np.radians, point1)

        # Deltas
        delta_lon = lon2 - lon1 
        delta_lat = lat2 - lat1 
        
        # haversine formula 
        a = np.sin(delta_lat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(delta_lon/2)**2
        c = 2 * np.arcsin(np.sqrt(a)) 
        r = 6371000 # Radius of earth in m
        return c * r

    leave_lat_add, leave_long_add = to_add.leave_location_lat, to_add.leave_location_long

    lat2, lon2 = map(np.radians, [leave_lat_add,leave_long_add])

    new_weights = [_edge_weight(_haversine(loc, lat2, lon2), max_dist) for loc in current_locs]

    return new_weights

def delete_rc(mat, i):
    # row
    n = mat.indptr[i+1] - mat.indptr[i]
    if n > 0:
        mat.data[mat.indptr[i]:-n] = mat.data[mat.indptr[i+1]:]
        mat.data = mat.data[:-n]
        mat.indices[mat.indptr[i]:-n] = mat.indices[mat.indptr[i+1]:]
        mat.indices = mat.indices[:-n]
    mat.indptr[i:-1] = mat.indptr[i+1:]
    mat.indptr[i:] -= n
    mat.indptr = mat.indptr[:-1]
    mat._shape = (mat._shape[0]-1, mat._shape[1])

    # col
    mat = mat.tocsc()
    n = mat.indptr[i+1] - mat.indptr[i]
    if n > 0:
        mat.data[mat.indptr[i]:-n] = mat.data[mat.indptr[i+1]:]
        mat.data = mat.data[:-n]
        mat.indices[mat.indptr[i]:-n] = mat.indices[mat.indptr[i+1]:]
        mat.indices = mat.indices[:-n]
    mat.indptr[i:-1] = mat.indptr[i+1:]
    mat.indptr[i:] -= n
    mat.indptr = mat.indptr[:-1]
    mat._shape = (mat._shape[0], mat._shape[1]-1)

    return mat.tocsr()

# Haversine function for stations
def haversine_station(point1, point2):
    # convert decimal degrees to radians
    lat1, lon1 = map(np.radians, point1)
    lat2, lon2 = map(np.radians, point2)

    # Deltas
    delta_lon = lon2 - lon1 
    delta_lat = lat2 - lat1 

    # haversine formula 
    a = np.sin(delta_lat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(delta_lon/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) 
    r = 6371000 # Radius of earth in m
    return c * r

# %%
# Load data
df = pd.read_csv('data/processed/VacancySplit.csv', index_col=0, parse_dates = [2]).astype({'time_to_reservation': 'float32', 'park_location_lat': 'float32', 'park_location_long': 'float32', 'leave_location_lat': 'float32', 'leave_location_long': 'float32', 'park_zone': 'int32', 'leave_zone': 'int32', 'park_fuel': 'int8', 'leave_fuel': 'int8', 'moved': 'float32', 'movedTF': 'bool'})

# Time variables
df['weekend'] = df.time.dt.weekday//5

# Time encoding
def circle_transform(col, max_val=86400):
    tot_sec = ((col - col.dt.normalize()) / pd.Timedelta('1 second')).astype(int)
    cos_val = np.cos(2*np.pi*tot_sec/max_val)
    sin_val = np.sin(2*np.pi*tot_sec/max_val)
    return cos_val, sin_val

df['Time_Cos'], df['Time_Sin'] = [x.values for x in circle_transform(df.time)]

# Join weather
df_weather = pd.read_csv('data/processed/weather.csv', index_col=0, parse_dates=[0])

# %%
df['timeH'] = df.time.round('H')
df = df.set_index('timeH').join(df_weather).reset_index(drop=True)
len(df)
# Out:
# 3401726

# %%
# Load data
df = pd.read_csv('data/processed/VacancySplit.csv', index_col=0, parse_dates = [2]).astype({'time_to_reservation': 'float32', 'park_location_lat': 'float32', 'park_location_long': 'float32', 'leave_location_lat': 'float32', 'leave_location_long': 'float32', 'park_zone': 'int32', 'leave_zone': 'int32', 'park_fuel': 'int8', 'leave_fuel': 'int8', 'moved': 'float32', 'movedTF': 'bool'})

# Time variables
df['weekend'] = df.time.dt.weekday//5

# Time encoding
def circle_transform(col, max_val=86400):
    tot_sec = ((col - col.dt.normalize()) / pd.Timedelta('1 second')).astype(int)
    cos_val = np.cos(2*np.pi*tot_sec/max_val)
    sin_val = np.sin(2*np.pi*tot_sec/max_val)
    return cos_val, sin_val

df['Time_Cos'], df['Time_Sin'] = [x.values for x in circle_transform(df.time)]

# Join weather
df_weather = pd.read_csv('data/processed/weather.csv', index_col=0, parse_dates=[0])
df['timeH'] = df.time.round('H')
df = df.set_index('timeH').join(df_weather).reset_index(drop=True)

# Create init graph
Start_Time = pd.Timestamp('2019-08-31 21:00:00')
End_Time = pd.Timestamp('2019-11-01 12:00:00')
start_df = df[df.time <= Start_Time]
propegate_df = df[(df.time > Start_Time) & (df.time <= End_Time)]

# Start
CarID_dict_start = dict(iter(start_df.groupby('car')))
Start_Garph_data = []

for sub_df in CarID_dict_start.values():
    last_obs = sub_df.iloc[-1]
    if last_obs.action: # True is park
        Start_Garph_data.append(last_obs)

start_df_graph = pd.DataFrame(Start_Garph_data).iloc[:,:-1]

# %%
Start_Garph_data
# Out:
# [car                      WBA1R5100J7B13378
#  time                   2019-08-31 20:07:41
#  time_to_reservation               3.598333
#  park_location_lat                55.690353
#  park_location_long               12.493163
#  leave_location_lat               55.690353
#  leave_location_long              12.493163
#  park_zone                           102631
#  leave_zone                          102631
#  park_fuel                               96
#  leave_fuel                              61
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.528747
#  Time_Sin                         -0.848779
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2737052, dtype: object,
#  car                      WBA1R5100K7D67688
#  time                   2019-08-31 16:50:02
#  time_to_reservation              16.251944
#  park_location_lat                55.716625
#  park_location_long               12.595335
#  leave_location_lat               55.716625
#  leave_location_long              12.595335
#  park_zone                           102332
#  leave_zone                          102332
#  park_fuel                               84
#  leave_fuel                              84
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                         -0.300567
#  Time_Sin                         -0.953761
#  mean_temp                             26.1
#  mean_wind_speed                        4.2
#  acc_precip                             0.0
#  bright_sunshine                       58.2
#  mean_pressure                       1014.2
#  mean_relative_hum                     60.9
#  mean_cloud_cover                       2.0
#  Name: 2735534, dtype: object,
#  car                      WBA1R5101J5K57918
#  time                   2019-08-31 19:12:46
#  time_to_reservation               2.161389
#  park_location_lat                55.666649
#  park_location_long               12.554121
#  leave_location_lat               55.666649
#  leave_location_long              12.554121
#  park_zone                           102812
#  leave_zone                          102812
#  park_fuel                               51
#  leave_fuel                              51
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.312197
#  Time_Sin                         -0.950017
#  mean_temp                             25.1
#  mean_wind_speed                        4.4
#  acc_precip                             0.0
#  bright_sunshine                       57.2
#  mean_pressure                       1012.9
#  mean_relative_hum                     66.7
#  mean_cloud_cover                       0.0
#  Name: 2736688, dtype: object,
#  car                      WBA1R5101J5K57921
#  time                   2019-08-31 20:54:27
#  time_to_reservation               1.548056
#  park_location_lat                55.725277
#  park_location_long               12.575421
#  leave_location_lat               55.725277
#  leave_location_long              12.575421
#  park_zone                           102311
#  leave_zone                          102311
#  park_fuel                               28
#  leave_fuel                              30
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.689778
#  Time_Sin                         -0.724021
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737288, dtype: object,
#  car                      WBA1R5101J5K58065
#  time                   2019-08-31 20:56:23
#  time_to_reservation               0.907778
#  park_location_lat                55.686661
#  park_location_long               12.532815
#  leave_location_lat               55.686661
#  leave_location_long              12.532815
#  park_zone                           147161
#  leave_zone                          147161
#  park_fuel                               88
#  leave_fuel                              88
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.695861
#  Time_Sin                         -0.718177
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737298, dtype: object,
#  car                      WBA1R5101J7B13325
#  time                   2019-08-31 18:10:23
#  time_to_reservation               4.413611
#  park_location_lat                55.722256
#  park_location_long               12.529609
#  leave_location_lat               55.722256
#  leave_location_long              12.529609
#  park_zone                           102522
#  leave_zone                          102522
#  park_fuel                               30
#  leave_fuel                              30
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                           0.04529
#  Time_Sin                         -0.998974
#  mean_temp                             26.0
#  mean_wind_speed                        4.3
#  acc_precip                             0.0
#  bright_sunshine                       53.8
#  mean_pressure                       1013.4
#  mean_relative_hum                     61.5
#  mean_cloud_cover                       0.0
#  Name: 2736187, dtype: object,
#  car                      WBA1R5101J7B13938
#  time                   2019-08-31 17:58:44
#  time_to_reservation               3.508333
#  park_location_lat                55.678612
#  park_location_long               12.563987
#  leave_location_lat               55.678612
#  leave_location_long              12.563987
#  park_zone                           102162
#  leave_zone                          102162
#  park_fuel                               34
#  leave_fuel                              34
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                         -0.005527
#  Time_Sin                         -0.999985
#  mean_temp                             26.0
#  mean_wind_speed                        4.3
#  acc_precip                             0.0
#  bright_sunshine                       53.8
#  mean_pressure                       1013.4
#  mean_relative_hum                     61.5
#  mean_cloud_cover                       0.0
#  Name: 2736104, dtype: object,
#  car                      WBA1R5101K5N19311
#  time                   2019-08-31 20:57:19
#  time_to_reservation              17.363611
#  park_location_lat                55.644798
#  park_location_long               12.627503
#  leave_location_lat               55.644798
#  leave_location_long              12.627503
#  park_zone                           103231
#  leave_zone                          103231
#  park_fuel                               44
#  leave_fuel                              15
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                           0.69878
#  Time_Sin                         -0.715337
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737303, dtype: object,
#  car                      WBA1R5101K7D91918
#  time                   2019-08-31 19:27:00
#  time_to_reservation               1.867222
#  park_location_lat                55.647911
#  park_location_long               12.548234
#  leave_location_lat               55.647911
#  leave_location_long              12.548234
#  park_zone                           102871
#  leave_zone                          102871
#  park_fuel                               21
#  leave_fuel                              15
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.370557
#  Time_Sin                          -0.92881
#  mean_temp                             25.1
#  mean_wind_speed                        4.4
#  acc_precip                             0.0
#  bright_sunshine                       57.2
#  mean_pressure                       1012.9
#  mean_relative_hum                     66.7
#  mean_cloud_cover                       0.0
#  Name: 2736785, dtype: object,
#  car                      WBA1R5102J5K57927
#  time                   2019-08-31 18:46:12
#  time_to_reservation               3.532778
#  park_location_lat                55.695133
#  park_location_long               12.501148
#  leave_location_lat               55.695133
#  leave_location_long              12.501148
#  park_zone                           102622
#  leave_zone                          102622
#  park_fuel                               44
#  leave_fuel                              44
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.200223
#  Time_Sin                          -0.97975
#  mean_temp                             25.1
#  mean_wind_speed                        4.4
#  acc_precip                             0.0
#  bright_sunshine                       57.2
#  mean_pressure                       1012.9
#  mean_relative_hum                     66.7
#  mean_cloud_cover                       0.0
#  Name: 2736484, dtype: object,
#  car                      WBA1R5102J5K58060
#  time                   2019-08-31 18:52:49
#  time_to_reservation                 7.3925
#  park_location_lat                55.688126
#  park_location_long               12.556644
#  leave_location_lat               55.688126
#  leave_location_long              12.556644
#  park_zone                           102445
#  leave_zone                          102445
#  park_fuel                               73
#  leave_fuel                              73
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.228422
#  Time_Sin                         -0.973562
#  mean_temp                             25.1
#  mean_wind_speed                        4.4
#  acc_precip                             0.0
#  bright_sunshine                       57.2
#  mean_pressure                       1012.9
#  mean_relative_hum                     66.7
#  mean_cloud_cover                       0.0
#  Name: 2736535, dtype: object,
#  car                      WBA1R5102J5K58091
#  time                   2019-08-31 20:09:51
#  time_to_reservation                   0.87
#  park_location_lat                55.685471
#  park_location_long               12.482958
#  leave_location_lat               55.685471
#  leave_location_long              12.482958
#  park_zone                           102632
#  leave_zone                          102632
#  park_fuel                               92
#  leave_fuel                              92
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.536747
#  Time_Sin                         -0.843743
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2737059, dtype: object,
#  car                      WBA1R5103J5K57967
#  time                   2019-08-31 19:39:34
#  time_to_reservation               1.841667
#  park_location_lat                55.694592
#  park_location_long               12.589759
#  leave_location_lat               55.694592
#  leave_location_long              12.589759
#  park_zone                           102214
#  leave_zone                          102214
#  park_fuel                               41
#  leave_fuel                              41
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.420904
#  Time_Sin                         -0.907105
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2736863, dtype: object,
#  car                      WBA1R5103J5K58066
#  time                   2019-08-31 20:58:56
#  time_to_reservation               0.381667
#  park_location_lat                55.690037
#  park_location_long               12.562806
#  leave_location_lat               55.690037
#  leave_location_long              12.562806
#  park_zone                           102442
#  leave_zone                          102442
#  park_fuel                               57
#  leave_fuel                              59
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.703808
#  Time_Sin                          -0.71039
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737309, dtype: object,
#  car                      WBA1R5103J7B13388
#  time                   2019-08-31 20:46:13
#  time_to_reservation               0.905278
#  park_location_lat                55.731586
#  park_location_long               12.567811
#  leave_location_lat               55.731586
#  leave_location_long              12.567811
#  park_zone                           157143
#  leave_zone                          157143
#  park_fuel                               76
#  leave_fuel                              78
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.663328
#  Time_Sin                         -0.748329
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737249, dtype: object,
#  car                      WBA1R5103J7B13925
#  time                   2019-08-31 13:16:32
#  time_to_reservation              47.377224
#  park_location_lat                55.650139
#  park_location_long               12.512616
#  leave_location_lat               55.650139
#  leave_location_long              12.512616
#  park_zone                           102751
#  leave_zone                          102751
#  park_fuel                               80
#  leave_fuel                              80
#  engine                                118I
#  moved                                  0.0
#  prev_customer                        False
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                         -0.944758
#  Time_Sin                         -0.327768
#  mean_temp                             25.2
#  mean_wind_speed                        3.5
#  acc_precip                             0.0
#  bright_sunshine                       59.8
#  mean_pressure                       1017.5
#  mean_relative_hum                     66.1
#  mean_cloud_cover                       0.0
#  Name: 2734137, dtype: object,
#  car                      WBA1R5103J7B14248
#  time                   2019-08-31 16:13:35
#  time_to_reservation              44.409443
#  park_location_lat                55.634289
#  park_location_long               12.649727
#  leave_location_lat               55.634289
#  leave_location_long              12.649727
#  park_zone                           185121
#  leave_zone                          185121
#  park_fuel                               73
#  leave_fuel                              73
#  engine                                118I
#  moved                                  0.0
#  prev_customer                        False
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                         -0.447824
#  Time_Sin                         -0.894122
#  mean_temp                             26.0
#  mean_wind_speed                        3.6
#  acc_precip                             0.0
#  bright_sunshine                       46.9
#  mean_pressure                       1015.1
#  mean_relative_hum                     60.9
#  mean_cloud_cover                       6.0
#  Name: 2735270, dtype: object,
#  car                      WBA1R5103K7D67684
#  time                   2019-08-31 18:00:44
#  time_to_reservation               4.707778
#  park_location_lat                55.663788
#  park_location_long               12.573566
#  leave_location_lat               55.663788
#  leave_location_long              12.573566
#  park_zone                           103182
#  leave_zone                          103182
#  park_fuel                               48
#  leave_fuel                              50
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                            0.0032
#  Time_Sin                         -0.999995
#  mean_temp                             26.0
#  mean_wind_speed                        4.3
#  acc_precip                             0.0
#  bright_sunshine                       53.8
#  mean_pressure                       1013.4
#  mean_relative_hum                     61.5
#  mean_cloud_cover                       0.0
#  Name: 2736111, dtype: object,
#  car                      WBA1R5103K7D91919
#  time                   2019-08-31 20:29:42
#  time_to_reservation              12.209167
#  park_location_lat                55.643219
#  park_location_long               12.619013
#  leave_location_lat               55.643219
#  leave_location_long              12.619013
#  park_zone                           103232
#  leave_zone                          103232
#  park_fuel                               57
#  leave_fuel                              55
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.607722
#  Time_Sin                          -0.79415
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2737168, dtype: object,
#  car                      WBA1R5105J5K58067
#  time                   2019-08-31 19:41:10
#  time_to_reservation                 1.5825
#  park_location_lat                55.770111
#  park_location_long               12.516689
#  leave_location_lat               55.770111
#  leave_location_long              12.516689
#  park_zone                           173061
#  leave_zone                          173061
#  park_fuel                               78
#  leave_fuel                              78
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.427226
#  Time_Sin                         -0.904145
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2736876, dtype: object,
#  car                      WBA1R5105J7B14249
#  time                   2019-08-31 19:08:44
#  time_to_reservation              25.952499
#  park_location_lat                55.733353
#  park_location_long               12.439356
#  leave_location_lat               55.733353
#  leave_location_long              12.439356
#  park_zone                           163021
#  leave_zone                          163021
#  park_fuel                               78
#  leave_fuel                              76
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                           0.29543
#  Time_Sin                         -0.955364
#  mean_temp                             25.1
#  mean_wind_speed                        4.4
#  acc_precip                             0.0
#  bright_sunshine                       57.2
#  mean_pressure                       1012.9
#  mean_relative_hum                     66.7
#  mean_cloud_cover                       0.0
#  Name: 2736654, dtype: object,
#  car                      WBA1R5105K7D67685
#  time                   2019-08-31 20:41:35
#  time_to_reservation               0.372778
#  park_location_lat                55.648746
#  park_location_long                12.55157
#  leave_location_lat               55.648746
#  leave_location_long               12.55157
#  park_zone                           102851
#  leave_zone                          102851
#  park_fuel                               40
#  leave_fuel                              40
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.648065
#  Time_Sin                         -0.761585
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737225, dtype: object,
#  car                      WBA1R5106J5K57641
#  time                   2019-08-31 20:55:51
#  time_to_reservation               1.760833
#  park_location_lat                55.648903
#  park_location_long               12.537423
#  leave_location_lat               55.648903
#  leave_location_long              12.537423
#  park_zone                           102852
#  leave_zone                          102852
#  park_fuel                               40
#  leave_fuel                              40
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.694187
#  Time_Sin                         -0.719794
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737292, dtype: object,
#  car                      WBA1R5106J5K57963
#  time                   2019-08-31 20:33:12
#  time_to_reservation               3.878333
#  park_location_lat                55.711857
#  park_location_long               12.565904
#  leave_location_lat               55.711857
#  leave_location_long              12.565904
#  park_zone                           102412
#  leave_zone                          102412
#  park_fuel                               96
#  leave_fuel                              96
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.619779
#  Time_Sin                         -0.784776
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737186, dtype: object,
#  car                      WBA1R5106J5K58059
#  time                   2019-08-31 20:26:52
#  time_to_reservation               0.597778
#  park_location_lat                55.648293
#  park_location_long               12.552844
#  leave_location_lat               55.648293
#  leave_location_long              12.552844
#  park_zone                           102851
#  leave_zone                          102851
#  park_fuel                               90
#  leave_fuel                              90
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.597858
#  Time_Sin                         -0.801602
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2737154, dtype: object,
#  car                      WBA1R5106J5K58160
#  time                   2019-08-14 19:19:17
#  time_to_reservation             446.133606
#  park_location_lat                55.621529
#  park_location_long               12.606278
#  leave_location_lat               55.621529
#  leave_location_long              12.606278
#  park_zone                           185154
#  leave_zone                          185154
#  park_fuel                               92
#  leave_fuel                              90
#  engine                                118I
#  moved                                  0.0
#  prev_customer                        False
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  0
#  Time_Cos                           0.33908
#  Time_Sin                         -0.940758
#  mean_temp                              NaN
#  mean_wind_speed                        NaN
#  acc_precip                             NaN
#  bright_sunshine                        NaN
#  mean_pressure                          NaN
#  mean_relative_hum                      NaN
#  mean_cloud_cover                       NaN
#  Name: 2645230, dtype: object,
#  car                      WBA1R5106J7B13384
#  time                   2019-08-31 20:34:14
#  time_to_reservation               1.941111
#  park_location_lat                55.719234
#  park_location_long                12.58116
#  leave_location_lat               55.719234
#  leave_location_long               12.58116
#  park_zone                           102321
#  leave_zone                          102321
#  park_fuel                               38
#  leave_fuel                              12
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.623311
#  Time_Sin                         -0.781974
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737187, dtype: object,
#  car                      WBA1R5106J7B14311
#  time                   2019-08-31 17:00:17
#  time_to_reservation              20.914722
#  park_location_lat                55.713425
#  park_location_long               12.505719
#  leave_location_lat               55.713425
#  leave_location_long              12.505719
#  park_zone                           102562
#  leave_zone                          102562
#  park_fuel                               69
#  leave_fuel                              69
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                         -0.257625
#  Time_Sin                         -0.966245
#  mean_temp                             26.1
#  mean_wind_speed                        4.2
#  acc_precip                             0.0
#  bright_sunshine                       58.2
#  mean_pressure                       1014.2
#  mean_relative_hum                     60.9
#  mean_cloud_cover                       2.0
#  Name: 2735634, dtype: object,
#  car                      WBA1R5106J7B14485
#  time                   2019-08-31 18:20:28
#  time_to_reservation               3.804167
#  park_location_lat                55.698597
#  park_location_long               12.588519
#  leave_location_lat               55.698597
#  leave_location_long              12.588519
#  park_zone                           102352
#  leave_zone                          102352
#  park_fuel                               96
#  leave_fuel                              96
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.089184
#  Time_Sin                         -0.996015
#  mean_temp                             26.0
#  mean_wind_speed                        4.3
#  acc_precip                             0.0
#  bright_sunshine                       53.8
#  mean_pressure                       1013.4
#  mean_relative_hum                     61.5
#  mean_cloud_cover                       0.0
#  Name: 2736269, dtype: object,
#  car                      WBA1R5106K7D67677
#  time                   2019-08-31 17:20:00
#  time_to_reservation              22.121666
#  park_location_lat                55.716618
#  park_location_long                12.59476
#  leave_location_lat               55.716618
#  leave_location_long               12.59476
#  park_zone                           102332
#  leave_zone                          102332
#  park_fuel                               34
#  leave_fuel                              34
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                         -0.173648
#  Time_Sin                         -0.984808
#  mean_temp                             26.1
#  mean_wind_speed                        4.2
#  acc_precip                             0.0
#  bright_sunshine                       58.2
#  mean_pressure                       1014.2
#  mean_relative_hum                     60.9
#  mean_cloud_cover                       2.0
#  Name: 2735782, dtype: object,
#  car                      WBA1R5106K7D67727
#  time                   2019-08-31 20:03:59
#  time_to_reservation               1.710556
#  park_location_lat                55.666958
#  park_location_long               12.565728
#  leave_location_lat               55.666958
#  leave_location_long              12.565728
#  park_zone                           102181
#  leave_zone                          102181
#  park_fuel                               67
#  leave_fuel                              69
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.514976
#  Time_Sin                         -0.857205
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2737023, dtype: object,
#  car                      WBA1R5107J5K57440
#  time                   2019-08-31 20:58:45
#  time_to_reservation                 0.0275
#  park_location_lat                55.709759
#  park_location_long               12.512602
#  leave_location_lat               55.709759
#  leave_location_long              12.512602
#  park_zone                           102562
#  leave_zone                          102562
#  park_fuel                               84
#  leave_fuel                              84
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                           0.70324
#  Time_Sin                         -0.710953
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737307, dtype: object,
#  car                      WBA1R5107J5K57969
#  time                   2019-08-31 17:10:19
#  time_to_reservation              16.369444
#  park_location_lat                55.663231
#  park_location_long               12.592061
#  leave_location_lat               55.663231
#  leave_location_long              12.592061
#  park_zone                           103191
#  leave_zone                          103191
#  park_fuel                               96
#  leave_fuel                              96
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          -0.21509
#  Time_Sin                         -0.976594
#  mean_temp                             26.1
#  mean_wind_speed                        4.2
#  acc_precip                             0.0
#  bright_sunshine                       58.2
#  mean_pressure                       1014.2
#  mean_relative_hum                     60.9
#  mean_cloud_cover                       2.0
#  Name: 2735702, dtype: object,
#  car                      WBA1R5107J7B13944
#  time                   2019-08-31 20:31:12
#  time_to_reservation               2.718333
#  park_location_lat                55.693569
#  park_location_long               12.495633
#  leave_location_lat               55.693569
#  leave_location_long              12.495633
#  park_zone                           102631
#  leave_zone                          102631
#  park_fuel                               65
#  leave_fuel                              65
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.612907
#  Time_Sin                         -0.790155
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737178, dtype: object,
#  car                      WBA1R5107J7B14317
#  time                   2019-08-31 17:46:54
#  time_to_reservation               4.378889
#  park_location_lat                 55.71011
#  park_location_long               12.508722
#  leave_location_lat                55.71011
#  leave_location_long              12.508722
#  park_zone                           102562
#  leave_zone                          102562
#  park_fuel                               38
#  leave_fuel                              40
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                         -0.057128
#  Time_Sin                         -0.998367
#  mean_temp                             26.0
#  mean_wind_speed                        4.3
#  acc_precip                             0.0
#  bright_sunshine                       53.8
#  mean_pressure                       1013.4
#  mean_relative_hum                     61.5
#  mean_cloud_cover                       0.0
#  Name: 2736004, dtype: object,
#  car                      WBA1R5107J7B14320
#  time                   2019-08-31 18:06:31
#  time_to_reservation               3.180556
#  park_location_lat                55.702114
#  park_location_long               12.454223
#  leave_location_lat               55.702114
#  leave_location_long              12.454223
#  park_zone                           175044
#  leave_zone                          175044
#  park_fuel                               76
#  leave_fuel                              78
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                           0.02843
#  Time_Sin                         -0.999596
#  mean_temp                             26.0
#  mean_wind_speed                        4.3
#  acc_precip                             0.0
#  bright_sunshine                       53.8
#  mean_pressure                       1013.4
#  mean_relative_hum                     61.5
#  mean_cloud_cover                       0.0
#  Name: 2736153, dtype: object,
#  car                      WBA1R5108J5K57964
#  time                   2019-08-31 18:35:13
#  time_to_reservation                14.5275
#  park_location_lat                55.661846
#  park_location_long               12.597856
#  leave_location_lat               55.661846
#  leave_location_long              12.597856
#  park_zone                           103173
#  leave_zone                          103173
#  park_fuel                               94
#  leave_fuel                              94
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.153058
#  Time_Sin                         -0.988217
#  mean_temp                             25.1
#  mean_wind_speed                        4.4
#  acc_precip                             0.0
#  bright_sunshine                       57.2
#  mean_pressure                       1012.9
#  mean_relative_hum                     66.7
#  mean_cloud_cover                       0.0
#  Name: 2736393, dtype: object,
#  car                      WBA1R5108J5K58063
#  time                   2019-08-31 20:17:44
#  time_to_reservation               0.973889
#  park_location_lat                55.625443
#  park_location_long               12.575089
#  leave_location_lat               55.625443
#  leave_location_long              12.575089
#  park_zone                           103292
#  leave_zone                          103292
#  park_fuel                               44
#  leave_fuel                              44
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.565447
#  Time_Sin                         -0.824785
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2737110, dtype: object,
#  car                      WBA1R5108J7B14309
#  time                   2019-08-31 18:35:44
#  time_to_reservation                 9.9575
#  park_location_lat                55.733311
#  park_location_long               12.444936
#  leave_location_lat               55.733311
#  leave_location_long              12.444936
#  park_zone                           163021
#  leave_zone                          163021
#  park_fuel                               59
#  leave_fuel                              59
#  engine                                118I
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.155285
#  Time_Sin                          -0.98787
#  mean_temp                             25.1
#  mean_wind_speed                        4.4
#  acc_precip                             0.0
#  bright_sunshine                       57.2
#  mean_pressure                       1012.9
#  mean_relative_hum                     66.7
#  mean_cloud_cover                       0.0
#  Name: 2736398, dtype: object,
#  car                      WBA1R5108J7B14312
#  time                   2019-08-31 19:25:45
#  time_to_reservation               5.359445
#  park_location_lat                55.716686
#  park_location_long               12.595378
#  leave_location_lat               55.716686
#  leave_location_long              12.595378
#  park_zone                           102332
#  leave_zone                          102332
#  park_fuel                               94
# ...
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2737044, dtype: object,
#  car                      WMWXU7107KTM90607
#  time                   2019-08-31 19:54:12
#  time_to_reservation               1.225556
#  park_location_lat                55.693707
#  park_location_long               12.511536
#  leave_location_lat               55.693707
#  leave_location_long              12.511536
#  park_zone                           102554
#  leave_zone                          102554
#  park_fuel                               47
#  leave_fuel                              50
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.477925
#  Time_Sin                           -0.8784
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2736961, dtype: object,
#  car                      WMWXU7107KTM90610
#  time                   2019-08-31 16:55:59
#  time_to_reservation              18.263889
#  park_location_lat                55.713543
#  park_location_long               12.505802
#  leave_location_lat               55.713543
#  leave_location_long              12.505802
#  park_zone                           102562
#  leave_zone                          102562
#  park_fuel                               35
#  leave_fuel                              35
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                         -0.275707
#  Time_Sin                         -0.961242
#  mean_temp                             26.1
#  mean_wind_speed                        4.2
#  acc_precip                             0.0
#  bright_sunshine                       58.2
#  mean_pressure                       1014.2
#  mean_relative_hum                     60.9
#  mean_cloud_cover                       2.0
#  Name: 2735599, dtype: object,
#  car                      WMWXU7107KTM90624
#  time                   2019-08-30 21:51:37
#  time_to_reservation              26.591667
#  park_location_lat                55.602695
#  park_location_long               12.658855
#  leave_location_lat               55.602695
#  leave_location_long              12.658855
#  park_zone                           155013
#  leave_zone                          155013
#  park_fuel                               52
#  leave_fuel                              55
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                        False
#  movedTF                              False
#  action                                True
#  weekend                                  0
#  Time_Cos                          0.847161
#  Time_Sin                         -0.531337
#  mean_temp                             19.5
#  mean_wind_speed                        2.2
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1021.9
#  mean_relative_hum                     84.2
#  mean_cloud_cover                       4.0
#  Name: 2731205, dtype: object,
#  car                      WMWXU7108KTM90583
#  time                   2019-08-31 19:03:43
#  time_to_reservation               3.014167
#  park_location_lat                55.688614
#  park_location_long                 12.5411
#  leave_location_lat               55.688614
#  leave_location_long                12.5411
#  park_zone                           102455
#  leave_zone                          102455
#  park_fuel                               47
#  leave_fuel                              50
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.274449
#  Time_Sin                         -0.961602
#  mean_temp                             25.1
#  mean_wind_speed                        4.4
#  acc_precip                             0.0
#  bright_sunshine                       57.2
#  mean_pressure                       1012.9
#  mean_relative_hum                     66.7
#  mean_cloud_cover                       0.0
#  Name: 2736609, dtype: object,
#  car                      WMWXU7108KTM90602
#  time                   2019-08-31 18:55:12
#  time_to_reservation               8.896389
#  park_location_lat                55.681194
#  park_location_long               12.564663
#  leave_location_lat               55.681194
#  leave_location_long              12.564663
#  park_zone                           102152
#  leave_zone                          102152
#  park_fuel                              100
#  leave_fuel                              99
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.238533
#  Time_Sin                         -0.971134
#  mean_temp                             25.1
#  mean_wind_speed                        4.4
#  acc_precip                             0.0
#  bright_sunshine                       57.2
#  mean_pressure                       1012.9
#  mean_relative_hum                     66.7
#  mean_cloud_cover                       0.0
#  Name: 2736554, dtype: object,
#  car                      WMWXU7108KTM90616
#  time                   2019-08-31 17:42:22
#  time_to_reservation               3.466667
#  park_location_lat                55.770111
#  park_location_long               12.516689
#  leave_location_lat               55.770111
#  leave_location_long              12.516689
#  park_zone                           173061
#  leave_zone                          173061
#  park_fuel                               32
#  leave_fuel                              32
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                         -0.076864
#  Time_Sin                         -0.997042
#  mean_temp                             26.0
#  mean_wind_speed                        4.3
#  acc_precip                             0.0
#  bright_sunshine                       53.8
#  mean_pressure                       1013.4
#  mean_relative_hum                     61.5
#  mean_cloud_cover                       0.0
#  Name: 2735971, dtype: object,
#  car                      WMWXU7108KTM91328
#  time                   2019-08-31 19:47:38
#  time_to_reservation               1.317222
#  park_location_lat                 55.70948
#  park_location_long               12.561972
#  leave_location_lat                55.70948
#  leave_location_long              12.561972
#  park_zone                           102411
#  leave_zone                          102411
#  park_fuel                               70
#  leave_fuel                              70
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.452564
#  Time_Sin                         -0.891732
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2736922, dtype: object,
#  car                      WMWXU7108KTM91409
#  time                   2019-08-31 19:45:12
#  time_to_reservation              10.704722
#  park_location_lat                55.700504
#  park_location_long                12.55415
#  leave_location_lat               55.700504
#  leave_location_long               12.55415
#  park_zone                           102432
#  leave_zone                          102432
#  park_fuel                               82
#  leave_fuel                              85
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.443071
#  Time_Sin                         -0.896486
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2736909, dtype: object,
#  car                      WMWXU7109KTM90592
#  time                   2019-08-31 20:48:33
#  time_to_reservation               1.893889
#  park_location_lat                55.634796
#  park_location_long               12.621698
#  leave_location_lat               55.634796
#  leave_location_long              12.621698
#  park_zone                           185132
#  leave_zone                          185132
#  park_fuel                               25
#  leave_fuel                              30
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.670912
#  Time_Sin                         -0.741537
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737259, dtype: object,
#  car                      WMWXU7109KTM91323
#  time                   2019-08-31 20:36:10
#  time_to_reservation               0.503889
#  park_location_lat                55.670658
#  park_location_long               12.582522
#  leave_location_lat               55.670658
#  leave_location_long              12.582522
#  park_zone                           103142
#  leave_zone                          103142
#  park_fuel                               85
#  leave_fuel                              85
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.629885
#  Time_Sin                         -0.776688
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737195, dtype: object,
#  car                      WMWXU710XKTM90603
#  time                   2019-08-31 20:29:50
#  time_to_reservation              15.093333
#  park_location_lat                55.705463
#  park_location_long                12.53502
#  leave_location_lat               55.705463
#  leave_location_long               12.53502
#  park_zone                           102532
#  leave_zone                          102532
#  park_fuel                               75
#  leave_fuel                              77
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.608184
#  Time_Sin                         -0.793796
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2737169, dtype: object,
#  car                      WMWXU710XKTM90617
#  time                   2019-08-31 20:32:53
#  time_to_reservation               1.123333
#  park_location_lat                55.679897
#  park_location_long               12.525328
#  leave_location_lat               55.679897
#  leave_location_long              12.525328
#  park_zone                           147152
#  leave_zone                          147152
#  park_fuel                               90
#  leave_fuel                              90
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                        False
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.618694
#  Time_Sin                         -0.785632
#  mean_temp                             23.2
#  mean_wind_speed                        2.5
#  acc_precip                             0.0
#  bright_sunshine                        0.0
#  mean_pressure                       1012.0
#  mean_relative_hum                     76.6
#  mean_cloud_cover                       0.0
#  Name: 2737184, dtype: object,
#  car                      WMWXU710XKTM91735
#  time                   2019-08-31 19:40:47
#  time_to_reservation               2.063611
#  park_location_lat                55.786522
#  park_location_long               12.517077
#  leave_location_lat               55.786522
#  leave_location_long              12.517077
#  park_zone                           173041
#  leave_zone                          173041
#  park_fuel                               80
#  leave_fuel                              80
#  engine                              COOPER
#  moved                                  0.0
#  prev_customer                         True
#  next_customer                         True
#  movedTF                              False
#  action                                True
#  weekend                                  1
#  Time_Cos                          0.425713
#  Time_Sin                         -0.904858
#  mean_temp                             24.0
#  mean_wind_speed                        3.3
#  acc_precip                             0.0
#  bright_sunshine                       40.5
#  mean_pressure                       1012.3
#  mean_relative_hum                     72.9
#  mean_cloud_cover                       0.0
#  Name: 2736874, dtype: object]

# %%
# Haversine function
def haversine(point1, point2):
    # convert decimal degrees to radians
    lat1, lon1 = map(np.radians, point1)
    lat2, lon2 = map(np.radians, point2)

    # Deltas
    delta_lon = lon2 - lon1 
    delta_lat = lat2 - lat1 

    # haversine formula 
    a = np.sin(delta_lat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(delta_lon/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) 
    r = 6371000 # Radius of earth in m
    return c * r

# Add dist to station
with open('data/processed/Train_stations.pickle', 'rb') as handle:
    Stations = pickle.load(handle)


#start_df_graph['dist_to_station'] = [min({k:haversine(v,r[1].values) for k,v in Stations.items()}.values()) for r in start_df_graph[['park_location_lat',	'park_location_long']].iterrows()]
#propegate_df['dist_to_station'] = [min({k:haversine(v,r[1].values) for k,v in Stations.items()}.values()) for r in tqdm(propegate_df[['park_location_lat',	'park_location_long']].iterrows(), total = len(propegate_df))]

# %%
# Adj matrix
A = pd.DataFrame(data = [[haversine_start(start_df_graph, car1, car2) for car1 in start_df_graph.car] for car2 in tqdm(start_df_graph.car)], index = start_df_graph.car, columns=start_df_graph.car, dtype='float16')

# And make it sparse
As = sparse.csr_matrix(A.values)

# Populate
Graph_dict = {pd.Timestamp('2019-08-31 21:00:00'): (start_df_graph ,As)}
node_data = start_df_graph.set_index('car')
# Out:
# 100%|██████████| 315/315 [02:59<00:00,  1.76it/s]

# %%
locs = [[attr['leave_location_lat'], attr['leave_location_long']] for _, attr in node_data.iterrows()]

# %%
start_df_graph
# Out:
#                        car                time  time_to_reservation  \
# 2737052  WBA1R5100J7B13378 2019-08-31 20:07:41             3.598333
# 2735534  WBA1R5100K7D67688 2019-08-31 16:50:02            16.251944
# 2736688  WBA1R5101J5K57918 2019-08-31 19:12:46             2.161389
# 2737288  WBA1R5101J5K57921 2019-08-31 20:54:27             1.548056
# 2737298  WBA1R5101J5K58065 2019-08-31 20:56:23             0.907778
# ...                    ...                 ...                  ...
# 2737259  WMWXU7109KTM90592 2019-08-31 20:48:33             1.893889
# 2737195  WMWXU7109KTM91323 2019-08-31 20:36:10             0.503889
# 2737169  WMWXU710XKTM90603 2019-08-31 20:29:50            15.093333
# 2737184  WMWXU710XKTM90617 2019-08-31 20:32:53             1.123333
# 2736874  WMWXU710XKTM91735 2019-08-31 19:40:47             2.063611
#
#          park_location_lat  park_location_long  leave_location_lat  \
# 2737052          55.690353           12.493163           55.690353
# 2735534          55.716625           12.595335           55.716625
# 2736688          55.666649           12.554121           55.666649
# 2737288          55.725277           12.575421           55.725277
# 2737298          55.686661           12.532815           55.686661
# ...                    ...                 ...                 ...
# 2737259          55.634796           12.621698           55.634796
# 2737195          55.670658           12.582522           55.670658
# 2737169          55.705463           12.535020           55.705463
# 2737184          55.679897           12.525328           55.679897
# 2736874          55.786522           12.517077           55.786522
#
#          leave_location_long  park_zone  leave_zone  park_fuel  ...  weekend  \
# 2737052            12.493163     102631      102631         96  ...        1
# 2735534            12.595335     102332      102332         84  ...        1
# 2736688            12.554121     102812      102812         51  ...        1
# 2737288            12.575421     102311      102311         28  ...        1
# 2737298            12.532815     147161      147161         88  ...        1
# ...                      ...        ...         ...        ...  ...      ...
# 2737259            12.621698     185132      185132         25  ...        1
# 2737195            12.582522     103142      103142         85  ...        1
# 2737169            12.535020     102532      102532         75  ...        1
# 2737184            12.525328     147152      147152         90  ...        1
# 2736874            12.517077     173041      173041         80  ...        1
#
#          Time_Cos  Time_Sin  mean_temp  mean_wind_speed  acc_precip  \
# 2737052  0.528747 -0.848779       24.0              3.3         0.0
# 2735534 -0.300567 -0.953761       26.1              4.2         0.0
# 2736688  0.312197 -0.950017       25.1              4.4         0.0
# 2737288  0.689778 -0.724021       23.2              2.5         0.0
# 2737298  0.695861 -0.718177       23.2              2.5         0.0
# ...           ...       ...        ...              ...         ...
# 2737259  0.670912 -0.741537       23.2              2.5         0.0
# 2737195  0.629885 -0.776688       23.2              2.5         0.0
# 2737169  0.608184 -0.793796       24.0              3.3         0.0
# 2737184  0.618694 -0.785632       23.2              2.5         0.0
# 2736874  0.425713 -0.904858       24.0              3.3         0.0
#
#          bright_sunshine  mean_pressure  mean_relative_hum  dist_to_station
# 2737052             40.5         1012.3               72.9       362.850961
# 2735534             58.2         1014.2               60.9       532.505078
# 2736688             57.2         1012.9               66.7       342.634371
# 2737288              0.0         1012.0               76.6       797.583821
# 2737298              0.0         1012.0               76.6        68.074730
# ...                  ...            ...                ...              ...
# 2737259              0.0         1012.0               76.6      1248.688496
# 2737195              0.0         1012.0               76.6       575.759061
# 2737169             40.5         1012.3               72.9       397.887191
# 2737184              0.0         1012.0               76.6       248.411684
# 2736874             40.5         1012.3               72.9      2129.769989
#
# [315 rows x 27 columns]

# %%
next_row.rename(index = next_row['car']).iloc[1:]
# Out:
# time                   2019-08-31 21:00:07
# time_to_reservation               6.386111
# park_location_lat                55.685123
# park_location_long               12.539447
# leave_location_lat               55.685123
# leave_location_long              12.539447
# park_zone                           147121
# leave_zone                          147121
# park_fuel                               56
# leave_fuel                              55
# engine                                  I3
# moved                                  0.0
# prev_customer                         True
# next_customer                         True
# movedTF                              False
# action                                True
# weekend                                  1
# Time_Cos                          0.707467
# Time_Sin                         -0.706747
# mean_temp                             23.2
# mean_wind_speed                        2.5
# acc_precip                             0.0
# bright_sunshine                        0.0
# mean_pressure                       1012.0
# mean_relative_hum                     76.6
# mean_cloud_cover                       0.0
# dist_to_station                 420.224846
# Name: WBY8P2108K7D87711, dtype: object

# %%
for idx, next_row in tqdm(propegate_df.iterrows(), total = propegate_df.shape[0]):
    if next_row.action: # True is park
        # Get current locs
        locs = [[attr['leave_location_lat'], attr['leave_location_long']] for _, attr in node_data.iterrows()]
        
        # Add to node data
        node_data = node_data.append(next_row.rename(index = next_row['car']).iloc[1:27], verify_integrity = True)

        # Calculate new weights
        new_weights = haversine_add(locs, next_row, max_dist = 1500)

        # Add new weights to adjacency
        As = sparse.hstack([sparse.vstack([As,sparse.csr_matrix(new_weights)]).tocsc(), sparse.csc_matrix(new_weights+[1]).T]).tocsr()

    else:
        # Getindex
        idx_to_drop = np.where(node_data.index == next_row.car)[0][0]

        # Drop it
        As = delete_rc(As, idx_to_drop)

        # Drop from feature-matrix
        node_data.drop(index = next_row.car, inplace=True)
        
    # Save graph if new time 
    if positive_time.get(idx):
        Graph_dict[next_row.time] = (node_data.copy(), As.copy())

    # Save file every day on last obs
    if new_day[idx]:
        f_name = next_row.time.strftime('data/processed/Graphs/%Y%m%d')+'.pickle'
        with open(f_name, 'wb') as handle:
            pickle.dump(Graph_dict, handle, pickle.HIGHEST_PROTOCOL)

        # Clear memory
        Graph_dict = {}

# %%
idx, next_row = next(iter(propegate_df.iloc[2:].iterrows()))

# %%
next_row
# Out:
# car                      WBY8P2108K7D87711
# time                   2019-08-31 21:00:07
# time_to_reservation               6.386111
# park_location_lat                55.685123
# park_location_long               12.539447
# leave_location_lat               55.685123
# leave_location_long              12.539447
# park_zone                           147121
# leave_zone                          147121
# park_fuel                               56
# leave_fuel                              55
# engine                                  I3
# moved                                  0.0
# prev_customer                         True
# next_customer                         True
# movedTF                              False
# action                                True
# weekend                                  1
# Time_Cos                          0.707467
# Time_Sin                         -0.706747
# mean_temp                             23.2
# mean_wind_speed                        2.5
# acc_precip                             0.0
# bright_sunshine                        0.0
# mean_pressure                       1012.0
# mean_relative_hum                     76.6
# mean_cloud_cover                       0.0
# dist_to_station                 420.224846
# Name: 2737319, dtype: object

# %%
with open('data/processed/Graphs/20190904.pickle', 'rb') as handle:
    ttt = pickle.load(handle)

# %%
next(iter(ttt.values()))[0].columns
# Out:
# Index(['time', 'time_to_reservation', 'park_location_lat',
#        'park_location_long', 'leave_location_lat', 'leave_location_long',
#        'park_zone', 'leave_zone', 'park_fuel', 'leave_fuel', 'engine', 'moved',
#        'prev_customer', 'next_customer', 'movedTF', 'action', 'weekend',
#        'Time_Cos', 'Time_Sin', 'mean_temp', 'mean_wind_speed', 'acc_precip',
#        'bright_sunshine', 'mean_pressure', 'mean_relative_hum',
#        'mean_cloud_cover', 'dist_to_station'],
#       dtype='object')

# %%
import pandas as pd
import glob
from tqdm import tqdm
import pickle

files = glob.glob("data/processed/Graphs/*")

# %%
cols = ['time', 'time_to_reservation', 'park_location_lat', 'park_location_long', 'leave_location_lat', 'leave_location_long','park_zone', 'leave_zone', 'park_fuel', 'leave_fuel', 'engine', 'moved','prev_customer', 'next_customer',
        'movedTF', 'action', 'weekend', 'Time_Cos', 'Time_Sin', 'mean_temp', 'mean_wind_speed', 'acc_precip', 'bright_sunshine', 'mean_pressure', 'mean_relative_hum', 'mean_cloud_cover', 'dist_to_station', 'degree']
dfn = pd.DataFrame(columns = cols)
i = 0

for f in tqdm(files):
    with open(f, 'rb') as day_file:
        day = pickle.load(day_file)

    for attr, adj in day.values():
        dfn.loc[i] = list(attr.iloc[-1].values)+[adj.getrow(-1).sum()]
        i += 1
# Out:
# 100%|██████████| 61/61 [51:58<00:00, 51.13s/it]

# %%
df2 = dfn.sort_values(by='time').copy()

# %%
df2['timeh'] = df2.time.round('h').dt.hour
trafic_index = dict(df2.groupby('timeh').mean()['time_to_reservation'])
df2.drop(columns = ['timeh'], inplace=True)
df2['hour_index'] = df2.time.dt.hour.map(trafic_index)

# %%
# Only to customers
df2 = df2[df2.next_customer]
df2.drop(columns=['prev_customer', 'next_customer'], inplace = True)

# No more than 2 days
df2 = df2[df2.time_to_reservation < 48]

# Remove zones with too little support
df2 = df2[~df2.leave_zone.isin((df2.leave_zone.value_counts() < 30).index[df2.leave_zone.value_counts() < 30])]

# One hot encoding
df2 = pd.get_dummies(df2, columns = ['engine','leave_zone'], prefix=['eng','lz'])

# Drop those far away
df2 = df2[df2['dist_to_station'] <= 7000]

# %%
df2.drop(columns=['park_location_lat', 'park_location_long', 'leave_location_lat', 'leave_location_long', 'park_fuel', 'park_zone', 'moved', 'movedTF', 'action'], inplace = True)

# %%
df2
# Out:
#                       time  time_to_reservation leave_fuel weekend  Time_Cos  \
# 117130 2019-09-01 00:00:18            10.836945         38       1  0.999999
# 117131 2019-09-01 00:00:47            10.142222         38       1  0.999994
# 117132 2019-09-01 00:01:17             0.511111         32       1  0.999984
# 117133 2019-09-01 00:01:23             1.473056         65       1  0.999982
# 117134 2019-09-01 00:02:18             0.001389         38       1  0.999950
# ...                    ...                  ...        ...     ...       ...
# 2864   2019-10-31 23:53:28             2.346944         96       0  0.999594
# 2865   2019-10-31 23:54:14            10.204445         46       0  0.999683
# 2866   2019-10-31 23:54:24             2.144167         43       0  0.999701
# 2867   2019-10-31 23:55:53             0.490278         67       0  0.999839
# 2868   2019-10-31 23:56:55             7.462778        100       0  0.999910
#
#         Time_Sin  mean_temp  mean_wind_speed  acc_precip  bright_sunshine  \
# 117130  0.001309       22.4              3.6         2.4              0.0
# 117131  0.003418       22.4              3.6         2.4              0.0
# 117132  0.005600       22.4              3.6         2.4              0.0
# 117133  0.006036       22.4              3.6         2.4              0.0
# 117134  0.010035       22.4              3.6         2.4              0.0
# ...          ...        ...              ...         ...              ...
# 2864   -0.028503        6.8              2.2         0.0              0.0
# 2865   -0.025159        6.8              2.2         0.0              0.0
# 2866   -0.024432        6.8              2.2         0.0              0.0
# 2867   -0.017961        6.8              2.2         0.0              0.0
# 2868   -0.013453        6.8              2.2         0.0              0.0
#
#         ...  lz_185122  lz_185123  lz_185124  lz_185131  lz_185132  lz_185141  \
# 117130  ...          0          0          0          0          0          0
# 117131  ...          0          0          0          0          0          0
# 117132  ...          0          0          0          0          0          0
# 117133  ...          0          0          0          0          0          0
# 117134  ...          0          0          0          0          0          0
# ...     ...        ...        ...        ...        ...        ...        ...
# 2864    ...          0          0          0          0          0          0
# 2865    ...          0          0          0          0          0          0
# 2866    ...          0          0          0          0          0          0
# 2867    ...          0          0          0          0          0          0
# 2868    ...          0          0          0          0          0          0
#
#         lz_185142  lz_185143  lz_185154  lz_185203
# 117130          0          0          0          0
# 117131          0          0          0          0
# 117132          0          0          0          0
# 117133          0          0          0          0
# 117134          0          0          0          0
# ...           ...        ...        ...        ...
# 2864            0          0          0          0
# 2865            0          0          0          0
# 2866            0          0          0          0
# 2867            0          0          0          0
# 2868            0          0          0          0
#
# [155842 rows x 276 columns]
