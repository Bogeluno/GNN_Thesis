# %%
import re, pickle
from datetime import datetime, timedelta
import GPy
import numpy as np
import pandas as pd
import matplotlib.cm as cm
from matplotlib import pyplot as plt
from IPython.display import display
from mapsplotlib import mapsplot as mplt

# fix random generator seed (for reproducibility of results)
np.random.seed(42)

# matplotlib options
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)

# %%
# matplotlib options (for some reason, in many computers, needs to be run twice to take effect...)
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# # Load data

# %%
df = pd.read_excel("data/raw/DTU - data til case_LTMZones1.xlsx")
df.head()
# Out:
#    TurID              BilID  PersonID Latitude (Start) Longitude (Start)  \
# 0      1  WBY1Z21040V307905     32614        55.670268         12.586064
# 1      2  WBY1Z21040V308214     44363        55.687024         12.585952
# 2      3  WBY1Z21070V307929     38610        55.692382         12.583143
# 3      4  WBY1Z21040V307869     37425        55.630274         12.648864
# 4      5  WBY1Z21030V307877     24168        55.693602          12.53821
#
#   Latitude (Slut) Longitude (Slut) Reservationstidspunkt     Start tidspunkt  \
# 0       55.652954        12.544699   2017-08-16 14:40:29 2017-08-16 14:34:29
# 1       55.726655        12.553914   2017-08-16 14:42:00 2017-08-16 14:38:00
# 2       55.775655        12.513962   2017-07-31 07:28:38 2017-07-31 07:21:38
# 3       55.706866        12.587122   2017-07-31 20:31:07 2017-07-31 20:31:07
# 4       55.677484        12.489247   2017-07-31 20:48:30 2017-07-31 20:44:30
#
#        Slut tidspunkt  Alder Køn Batteristatus (start) Batteristatus (slut)  \
# 0 2017-08-16 14:52:55     32   M                    94                   91
# 1 2017-08-16 15:05:22     25   M                    48                   42
# 2 2017-08-01 12:49:44     21   M                     0                    0
# 3 2017-08-01 09:13:25     30   M                     0                    0
# 4 2017-08-01 08:52:43     28   M                     0                    0
#
#    Km kørt  FromZoneID  ToZoneID
# 0        5      103142    102851
# 1        7      102212    157231
# 2       19      102213    173051
# 3       18      185203    102341
# 4        5      102454    102771

# %%
# convert dates to datetime format
df["Reservationstidspunkt"] = pd.to_datetime(df["Reservationstidspunkt"], format="%Y-%m-%d %H:%M:%S")
df["Start tidspunkt"] = pd.to_datetime(df["Start tidspunkt"], format="%Y-%m-%d %H:%M:%S")
df["Slut tidspunkt"] = pd.to_datetime(df["Slut tidspunkt"], format="%Y-%m-%d %H:%M:%S")
df["date"] = df["Start tidspunkt"].dt.date

# %% [markdown]
# # Basic descriptive statistics

# %%
print("Total transactions:", len(df))
print("Total number of cars:", len(np.unique(df["BilID"])))
print("Number of unique customers:", len(np.unique(df["PersonID"])))
print("Period start:", df["date"].min())
print("Period end:", df["date"].max())
# Out:
# Total transactions: 366420
# Total number of cars: 347
# Number of unique customers: 25380
# Period start: 2017-07-31
# Period end: 2018-05-08

# %%
grouped = df.groupby("date")["TurID"].count()
plt.plot(grouped.index, grouped.values)
plt.xlabel("Date")
plt.ylabel("Num. trips")
plt.title("Number of trips over time")
plt.show()

# %%
plt.hist(df["Km kørt"], bins=range(40))
plt.title("Km driven")
plt.xlabel("Km")
plt.ylabel("Number of trips")
plt.show()

# %% [markdown]
# # Process data and generate demand and supply

# %%
zone_ids = np.unique((df["FromZoneID"] / 10).astype(np.int)).tolist()
for z_id in np.unique((df["ToZoneID"] / 10).astype(np.int)).tolist():
    if z_id not in zone_ids:
        zone_ids.append(z_id)
vehicle_ids = np.unique(df["BilID"])

# %%
# sort trips by start time
df_sorted = df.sort_values("Start tidspunkt")

n = 0
start_date = datetime(2017, 8, 5) # ignore data before this datetime
current_time = 0
current_date = start_date.strftime("%Y-%m-%d %H:00")
dates_demand = {}
demand = {}
demand_temp = {z_id:0 for z_id in zone_ids}
for ix, row in df_sorted.iterrows():
    n += 1
    if not n % 10000:
        print("%d of %d rows processed for far..." % (n, len(df)))
    
    # ignore invalid rows
    if row["BilID"] == '-':
        continue
    try:
        start_lat = float(row["Latitude (Start)"])
        start_lng = float(row["Longitude (Start)"])
        end_lat = float(row["Latitude (Slut)"])
        end_lng = float(row["Longitude (Slut)"])
    except:
        continue
    
    # skip the first days so that we can figure out the positions of all cars
    if row["Start tidspunkt"] < start_date:
        continue
    
    # get current time bin (by hour)
    time = int((row["Start tidspunkt"] - start_date).total_seconds() / 60 / 60)
    
    if time != current_time: # if time bin (hour) has changed
        
        # save demand (note that this is the demand for the current time bin)
        dates_demand[current_time] = current_date
        demand[current_time] = demand_temp
        
        # reset variables
        demand_temp = {z_id:0 for z_id in zone_ids}
        current_time = time
        current_date = row["Start tidspunkt"].strftime("%Y-%m-%d %H:00")
        
    # get origin and destination zones
    origin_zone = int(int(row["FromZoneID"]) / 10)
    destination_zone = int(int(row["ToZoneID"]) / 10)
    
    # update demand for corresponding zone
    demand_temp[origin_zone] += 1

print("Done!")
# Out:
# 10000 of 366420 rows processed for far...
# 20000 of 366420 rows processed for far...
# 30000 of 366420 rows processed for far...
# 40000 of 366420 rows processed for far...
# 50000 of 366420 rows processed for far...
# 60000 of 366420 rows processed for far...
# 70000 of 366420 rows processed for far...
# 80000 of 366420 rows processed for far...
# 90000 of 366420 rows processed for far...
# 100000 of 366420 rows processed for far...
# 110000 of 366420 rows processed for far...
# 120000 of 366420 rows processed for far...
# 130000 of 366420 rows processed for far...
# 140000 of 366420 rows processed for far...
# 150000 of 366420 rows processed for far...
# 160000 of 366420 rows processed for far...
# 170000 of 366420 rows processed for far...
# 180000 of 366420 rows processed for far...
# 190000 of 366420 rows processed for far...
# 200000 of 366420 rows processed for far...
# 210000 of 366420 rows processed for far...
# 220000 of 366420 rows processed for far...
# 230000 of 366420 rows processed for far...
# 240000 of 366420 rows processed for far...
# 250000 of 366420 rows processed for far...
# 260000 of 366420 rows processed for far...
# 270000 of 366420 rows processed for far...
# 280000 of 366420 rows processed for far...
# 290000 of 366420 rows processed for far...
# 300000 of 366420 rows processed for far...
# 310000 of 366420 rows processed for far...
# 320000 of 366420 rows processed for far...
# 330000 of 366420 rows processed for far...
# 340000 of 366420 rows processed for far...
# 350000 of 366420 rows processed for far...
# 360000 of 366420 rows processed for far...
# Done!

# %%
# sort trips by end time
df_sorted = df.sort_values("Slut tidspunkt")

# keep track of all vehicles at every time step
vehicle_pos = {v_id:None for v_id in vehicle_ids}
vehicle_zone = {v_id:None for v_id in vehicle_ids}
n = 0
start_date = datetime(2017, 8, 5) # ignore data before this datetime
current_time = 0
current_date = start_date.strftime("%Y-%m-%d %H:00")
dates_supply = {}
supply = {}
for ix, row in df_sorted.iterrows():
    n += 1
    if not n % 10000:
        print("%d of %d rows processed for far..." % (n, len(df)))
    
    # ignore invalid rows
    if row["BilID"] == '-':
        continue
    try:
        start_lat = float(row["Latitude (Start)"])
        start_lng = float(row["Longitude (Start)"])
        end_lat = float(row["Latitude (Slut)"])
        end_lng = float(row["Longitude (Slut)"])
    except:
        continue
    
    # skip the first days so that we can figure out the positions of all cars
    if row["Start tidspunkt"] < start_date:
        # save vehicle position for tracking
        vehicle_pos[row["BilID"]] = (end_lat, end_lng)
        continue
    
    # get current time bin (by hour)
    time = int((row["Slut tidspunkt"] - start_date).total_seconds() / 60 / 60)
    
    if time != current_time: # if time bin (hour) has changed
        # compute supply
        supply_temp = {z_id:0 for z_id in zone_ids}
        for v_id in vehicle_zone:
            if vehicle_zone[v_id] != None:
                supply_temp[vehicle_zone[v_id]] += 1
        
        # save supply (note that this will be supply for the next bin!)
        dates_supply[current_time+1] = row["Slut tidspunkt"].strftime("%Y-%m-%d %H:00")
        supply[current_time+1] = supply_temp
        
        # reset variables
        current_time = time
        current_date = row["Slut tidspunkt"].strftime("%Y-%m-%d %H:00")
        
    # get origin and destination zones
    origin_zone = int(int(row["FromZoneID"]) / 10)
    destination_zone = int(int(row["ToZoneID"]) / 10)
    
    # update vehicle position and zone in tracking
    vehicle_pos[row["BilID"]] = (end_lat, end_lng)
    vehicle_zone[row["BilID"]] = destination_zone

print("Done!")
# Out:
# 10000 of 366420 rows processed for far...
# 20000 of 366420 rows processed for far...
# 30000 of 366420 rows processed for far...
# 40000 of 366420 rows processed for far...
# 50000 of 366420 rows processed for far...
# 60000 of 366420 rows processed for far...
# 70000 of 366420 rows processed for far...
# 80000 of 366420 rows processed for far...
# 90000 of 366420 rows processed for far...
# 100000 of 366420 rows processed for far...
# 110000 of 366420 rows processed for far...
# 120000 of 366420 rows processed for far...
# 130000 of 366420 rows processed for far...
# 140000 of 366420 rows processed for far...
# 150000 of 366420 rows processed for far...
# 160000 of 366420 rows processed for far...
# 170000 of 366420 rows processed for far...
# 180000 of 366420 rows processed for far...
# 190000 of 366420 rows processed for far...
# 200000 of 366420 rows processed for far...
# 210000 of 366420 rows processed for far...
# 220000 of 366420 rows processed for far...
# 230000 of 366420 rows processed for far...
# 240000 of 366420 rows processed for far...
# 250000 of 366420 rows processed for far...
# 260000 of 366420 rows processed for far...
# 270000 of 366420 rows processed for far...
# 280000 of 366420 rows processed for far...
# 290000 of 366420 rows processed for far...
# 300000 of 366420 rows processed for far...
# 310000 of 366420 rows processed for far...
# 320000 of 366420 rows processed for far...
# 330000 of 366420 rows processed for far...
# 340000 of 366420 rows processed for far...
# 350000 of 366420 rows processed for far...
# 360000 of 366420 rows processed for far...
# Done!

# %%
# check fraction of cases in which demand is greater than (or equal to) the supply
total_cases = 0
boundary_cases = 0
problem_cases = 0
missings = 0
for t in demand:
    for z_id in zone_ids:
        if t not in supply.keys():
            missings += 1
            continue
        if demand[t][z_id] == supply[t][z_id]:
            boundary_cases += 1
        elif demand[t][z_id] > supply[t][z_id]:
            problem_cases += 1
        total_cases += 1

print("Total cases:", total_cases)
print("Total missings:", missings)
print("Total boundary cases: %d (%.1f perc.)" % (boundary_cases, 100.0*boundary_cases/total_cases))
print("Total problematic cases: %d (%.1f perc.)" % (problem_cases, 100.0*problem_cases/total_cases))
# Out:
# Total cases: 1185875
# Total missings: 1790
# Total boundary cases: 649897 (54.8 perc.)
# Total problematic cases: 10578 (0.9 perc.)

# %% [markdown]
# # Visualize data for an example zone

# %%
zone_id = 10222
demand_ts = [demand[t][zone_id] for t in demand if t in supply.keys()]
supply_ts = [supply[t][zone_id] for t in demand if t in supply.keys()]
print("Fraction of boundary cases: %.3f" % (np.sum(np.array(demand_ts) == np.array(supply_ts)) / len(demand_ts)),)
print("Fraction of problematic cases: %.3f" % (np.sum(np.array(demand_ts) > np.array(supply_ts)) / len(demand_ts)),)
plt.plot(demand_ts[:(24*7)], "r-")
plt.plot(supply_ts[:(24*7)], "b-")
plt.legend(["demand", "supply"], loc="upper left")
plt.show()
# Out:
# Fraction of boundary cases: 0.061
# Fraction of problematic cases: 0.029

# %%
zone_id = 10212
demand_ts = [demand[t][zone_id] for t in demand if t in supply.keys()]
supply_ts = [supply[t][zone_id] for t in demand if t in supply.keys()]
print("Fraction of boundary cases: %.3f" % (np.sum(np.array(demand_ts) == np.array(supply_ts)) / len(demand_ts)),)
print("Fraction of problematic cases: %.3f" % (np.sum(np.array(demand_ts) > np.array(supply_ts)) / len(demand_ts)),)
plt.plot(demand_ts[:(24*7)], "r-")
plt.plot(supply_ts[:(24*7)], "b-")
plt.legend(["demand", "supply"], loc="upper left")
plt.show()
# Out:
# Fraction of boundary cases: 0.334
# Fraction of problematic cases: 0.071

# %%
zone_id = 10211
demand_ts = [demand[t][zone_id] for t in demand if t in supply.keys()]
supply_ts = [supply[t][zone_id] for t in demand if t in supply.keys()]
print("Fraction of boundary cases: %.3f" % (np.sum(np.array(demand_ts) == np.array(supply_ts)) / len(demand_ts)),)
print("Fraction of problematic cases: %.3f" % (np.sum(np.array(demand_ts) > np.array(supply_ts)) / len(demand_ts)),)
plt.plot(demand_ts[:(24*7)], "r-")
plt.plot(supply_ts[:(24*7)], "b-")
plt.legend(["demand", "supply"], loc="upper left")
plt.show()
# Out:
# Fraction of boundary cases: 0.611
# Fraction of problematic cases: 0.020

# %%
zone_id = 10233
demand_ts = [demand[t][zone_id] for t in demand if t in supply.keys()]
supply_ts = [supply[t][zone_id] for t in demand if t in supply.keys()]
print("Fraction of boundary cases: %.3f" % (np.sum(np.array(demand_ts) == np.array(supply_ts)) / len(demand_ts)),)
print("Fraction of problematic cases: %.3f" % (np.sum(np.array(demand_ts) > np.array(supply_ts)) / len(demand_ts)),)
plt.plot(demand_ts[:(24*7)], "r-")
plt.plot(supply_ts[:(24*7)], "b-")
plt.legend(["demand", "supply"], loc="upper left")
plt.show()
# Out:
# Fraction of boundary cases: 0.020
# Fraction of problematic cases: 0.003

# %%
zone_id = 10223
demand_ts = [demand[t][zone_id] for t in demand if t in supply.keys()]
supply_ts = [supply[t][zone_id] for t in demand if t in supply.keys()]
print("Fraction of boundary cases: %.3f" % (np.sum(np.array(demand_ts) == np.array(supply_ts)) / len(demand_ts)),)
print("Fraction of problematic cases: %.3f" % (np.sum(np.array(demand_ts) > np.array(supply_ts)) / len(demand_ts)),)
plt.plot(demand_ts[:(24*7)], "r-")
plt.plot(supply_ts[:(24*7)], "b-")
plt.legend(["demand", "supply"], loc="upper left")
plt.show()
# Out:
# Fraction of boundary cases: 0.493
# Fraction of problematic cases: 0.034

# %% [markdown]
# # Zones with most demand

# %%
for z_id in zone_ids:
    demand_ts = [demand[t][z_id] for t in demand if t in supply.keys()]
    mean_demand = np.mean(demand_ts)
    if mean_demand < 1.5:
        continue
    print("Zone: %d -> Avg. demand: %.1f" % (z_id, mean_demand))
# Out:
# Zone: 10222 -> Avg. demand: 1.7
# Zone: 10234 -> Avg. demand: 1.9
# Zone: 10244 -> Avg. demand: 2.1
# Zone: 17304 -> Avg. demand: 1.6

# %% [markdown]
# # Save demand and supply data to disk

# %%
output_dir = "data/processed/demand_supply_level2"
dates_demand_rev = {v:k for k,v in dates_demand.items()}
dates_supply_rev = {v:k for k,v in dates_supply.items()}
for z_id in zone_ids:
    fw = open("%s/%d.csv" % (output_dir, z_id), "w")
    fw.write("time,demand,supply\n")
    current_time = start_date
    end_time = datetime(2018,5,1)
    added_zeros = 0
    count = 0
    while current_time < end_time:
        count += 1

        time_str = current_time.strftime("%Y-%m-%d %H:00")
        try:
            d = demand[dates_demand_rev[time_str]][z_id]
        except:
            added_zeros += 1
            d = 0
        try:
            s = supply[dates_supply_rev[time_str]][z_id]
        except:
            added_zeros += 1
            s = 0
        fw.write("%s,%d,%d\n" % (time_str,d,s))
        current_time += timedelta(hours=1)

    fw.close()
    print("Saved zone id %d. Count=%d, AddedZeros=%d" % (z_id, count, added_zeros))
# Out:
# Saved zone id 0. Count=6456, AddedZeros=24
# Saved zone id 10211. Count=6456, AddedZeros=24
# Saved zone id 10212. Count=6456, AddedZeros=24
# Saved zone id 10213. Count=6456, AddedZeros=24
# Saved zone id 10214. Count=6456, AddedZeros=24
# Saved zone id 10215. Count=6456, AddedZeros=24
# Saved zone id 10216. Count=6456, AddedZeros=24
# Saved zone id 10217. Count=6456, AddedZeros=24
# Saved zone id 10218. Count=6456, AddedZeros=24
# Saved zone id 10221. Count=6456, AddedZeros=24
# Saved zone id 10222. Count=6456, AddedZeros=24
# Saved zone id 10223. Count=6456, AddedZeros=24
# Saved zone id 10231. Count=6456, AddedZeros=24
# Saved zone id 10232. Count=6456, AddedZeros=24
# Saved zone id 10233. Count=6456, AddedZeros=24
# Saved zone id 10234. Count=6456, AddedZeros=24
# Saved zone id 10235. Count=6456, AddedZeros=24
# Saved zone id 10241. Count=6456, AddedZeros=24
# Saved zone id 10242. Count=6456, AddedZeros=24
# Saved zone id 10243. Count=6456, AddedZeros=24
# Saved zone id 10244. Count=6456, AddedZeros=24
# Saved zone id 10245. Count=6456, AddedZeros=24
# Saved zone id 10251. Count=6456, AddedZeros=24
# Saved zone id 10252. Count=6456, AddedZeros=24
# Saved zone id 10253. Count=6456, AddedZeros=24
# Saved zone id 10254. Count=6456, AddedZeros=24
# Saved zone id 10255. Count=6456, AddedZeros=24
# Saved zone id 10256. Count=6456, AddedZeros=24
# Saved zone id 10261. Count=6456, AddedZeros=24
# Saved zone id 10262. Count=6456, AddedZeros=24
# Saved zone id 10263. Count=6456, AddedZeros=24
# Saved zone id 10264. Count=6456, AddedZeros=24
# Saved zone id 10265. Count=6456, AddedZeros=24
# Saved zone id 10266. Count=6456, AddedZeros=24
# Saved zone id 10267. Count=6456, AddedZeros=24
# Saved zone id 10271. Count=6456, AddedZeros=24
# Saved zone id 10272. Count=6456, AddedZeros=24
# Saved zone id 10273. Count=6456, AddedZeros=24
# Saved zone id 10274. Count=6456, AddedZeros=24
# Saved zone id 10275. Count=6456, AddedZeros=24
# Saved zone id 10276. Count=6456, AddedZeros=24
# Saved zone id 10277. Count=6456, AddedZeros=24
# Saved zone id 10281. Count=6456, AddedZeros=24
# Saved zone id 10282. Count=6456, AddedZeros=24
# Saved zone id 10283. Count=6456, AddedZeros=24
# Saved zone id 10284. Count=6456, AddedZeros=24
# Saved zone id 10285. Count=6456, AddedZeros=24
# Saved zone id 10286. Count=6456, AddedZeros=24
# Saved zone id 10287. Count=6456, AddedZeros=24
# Saved zone id 10311. Count=6456, AddedZeros=24
# Saved zone id 10313. Count=6456, AddedZeros=24
# Saved zone id 10314. Count=6456, AddedZeros=24
# Saved zone id 10315. Count=6456, AddedZeros=24
# Saved zone id 10316. Count=6456, AddedZeros=24
# Saved zone id 10317. Count=6456, AddedZeros=24
# Saved zone id 10318. Count=6456, AddedZeros=24
# Saved zone id 10319. Count=6456, AddedZeros=24
# Saved zone id 10321. Count=6456, AddedZeros=24
# Saved zone id 10322. Count=6456, AddedZeros=24
# Saved zone id 10323. Count=6456, AddedZeros=24
# Saved zone id 10324. Count=6456, AddedZeros=24
# Saved zone id 10325. Count=6456, AddedZeros=24
# Saved zone id 10326. Count=6456, AddedZeros=24
# Saved zone id 10327. Count=6456, AddedZeros=24
# Saved zone id 10328. Count=6456, AddedZeros=24
# Saved zone id 10329. Count=6456, AddedZeros=24
# Saved zone id 14711. Count=6456, AddedZeros=24
# Saved zone id 14712. Count=6456, AddedZeros=24
# Saved zone id 14713. Count=6456, AddedZeros=24
# Saved zone id 14714. Count=6456, AddedZeros=24
# Saved zone id 14715. Count=6456, AddedZeros=24
# Saved zone id 14716. Count=6456, AddedZeros=24
# Saved zone id 14721. Count=6456, AddedZeros=24
# Saved zone id 14722. Count=6456, AddedZeros=24
# Saved zone id 14723. Count=6456, AddedZeros=24
# Saved zone id 14724. Count=6456, AddedZeros=24
# Saved zone id 14725. Count=6456, AddedZeros=24
# Saved zone id 15101. Count=6456, AddedZeros=24
# Saved zone id 15102. Count=6456, AddedZeros=24
# Saved zone id 15103. Count=6456, AddedZeros=24
# Saved zone id 15105. Count=6456, AddedZeros=24
# Saved zone id 15106. Count=6456, AddedZeros=24
# Saved zone id 15301. Count=6456, AddedZeros=24
# Saved zone id 15303. Count=6456, AddedZeros=24
# Saved zone id 15501. Count=6456, AddedZeros=24
# Saved zone id 15711. Count=6456, AddedZeros=24
# Saved zone id 15712. Count=6456, AddedZeros=24
# Saved zone id 15713. Count=6456, AddedZeros=24
# Saved zone id 15714. Count=6456, AddedZeros=24
# Saved zone id 15715. Count=6456, AddedZeros=24
# Saved zone id 15721. Count=6456, AddedZeros=24
# Saved zone id 15722. Count=6456, AddedZeros=24
# Saved zone id 15723. Count=6456, AddedZeros=24
# Saved zone id 15724. Count=6456, AddedZeros=24
# Saved zone id 15726. Count=6456, AddedZeros=24
# Saved zone id 15901. Count=6456, AddedZeros=24
# Saved zone id 15902. Count=6456, AddedZeros=24
# Saved zone id 15903. Count=6456, AddedZeros=24
# Saved zone id 15905. Count=6456, AddedZeros=24
# Saved zone id 15907. Count=6456, AddedZeros=24
# Saved zone id 15908. Count=6456, AddedZeros=24
# Saved zone id 16101. Count=6456, AddedZeros=24
# Saved zone id 16102. Count=6456, AddedZeros=24
# Saved zone id 16103. Count=6456, AddedZeros=24
# Saved zone id 16301. Count=6456, AddedZeros=24
# Saved zone id 16302. Count=6456, AddedZeros=24
# Saved zone id 16501. Count=6456, AddedZeros=24
# Saved zone id 16701. Count=6456, AddedZeros=24
# Saved zone id 16702. Count=6456, AddedZeros=24
# Saved zone id 16704. Count=6456, AddedZeros=24
# Saved zone id 16901. Count=6456, AddedZeros=24
# Saved zone id 16902. Count=6456, AddedZeros=24
# Saved zone id 16904. Count=6456, AddedZeros=24
# Saved zone id 17302. Count=6456, AddedZeros=24
# Saved zone id 17303. Count=6456, AddedZeros=24
# Saved zone id 17304. Count=6456, AddedZeros=24
# Saved zone id 17305. Count=6456, AddedZeros=24
# Saved zone id 17306. Count=6456, AddedZeros=24
# Saved zone id 17307. Count=6456, AddedZeros=24
# Saved zone id 17502. Count=6456, AddedZeros=24
# Saved zone id 17503. Count=6456, AddedZeros=24
# Saved zone id 17504. Count=6456, AddedZeros=24
# Saved zone id 17505. Count=6456, AddedZeros=24
# Saved zone id 18301. Count=6456, AddedZeros=24
# Saved zone id 18512. Count=6456, AddedZeros=24
# Saved zone id 18513. Count=6456, AddedZeros=24
# Saved zone id 18514. Count=6456, AddedZeros=24
# Saved zone id 18515. Count=6456, AddedZeros=24
# Saved zone id 18520. Count=6456, AddedZeros=24
# Saved zone id 19003. Count=6456, AddedZeros=24
# Saved zone id 19004. Count=6456, AddedZeros=24
# Saved zone id 20102. Count=6456, AddedZeros=24
# Saved zone id 21006. Count=6456, AddedZeros=24
# Saved zone id 21701. Count=6456, AddedZeros=24
# Saved zone id 21702. Count=6456, AddedZeros=24
# Saved zone id 21704. Count=6456, AddedZeros=24
# Saved zone id 21708. Count=6456, AddedZeros=24
# Saved zone id 21903. Count=6456, AddedZeros=24
# Saved zone id 21906. Count=6456, AddedZeros=24
# Saved zone id 22301. Count=6456, AddedZeros=24
# Saved zone id 22302. Count=6456, AddedZeros=24
# Saved zone id 23001. Count=6456, AddedZeros=24
# Saved zone id 23004. Count=6456, AddedZeros=24
# Saved zone id 23007. Count=6456, AddedZeros=24
# Saved zone id 24001. Count=6456, AddedZeros=24
# Saved zone id 24005. Count=6456, AddedZeros=24
# Saved zone id 26523. Count=6456, AddedZeros=24
# Saved zone id 26524. Count=6456, AddedZeros=24
# Saved zone id 26901. Count=6456, AddedZeros=24
# Saved zone id 27024. Count=6456, AddedZeros=24
# Saved zone id 31614. Count=6456, AddedZeros=24
# Saved zone id 15107. Count=6456, AddedZeros=24
# Saved zone id 15302. Count=6456, AddedZeros=24
# Saved zone id 15502. Count=6456, AddedZeros=24
# Saved zone id 15725. Count=6456, AddedZeros=24
# Saved zone id 15906. Count=6456, AddedZeros=24
# Saved zone id 16503. Count=6456, AddedZeros=24
# Saved zone id 16703. Count=6456, AddedZeros=24
# Saved zone id 16706. Count=6456, AddedZeros=24
# Saved zone id 16905. Count=6456, AddedZeros=24
# Saved zone id 17501. Count=6456, AddedZeros=24
# Saved zone id 18302. Count=6456, AddedZeros=24
# Saved zone id 18516. Count=6456, AddedZeros=24
# Saved zone id 18517. Count=6456, AddedZeros=24
# Saved zone id 18702. Count=6456, AddedZeros=24
# Saved zone id 19005. Count=6456, AddedZeros=24
# Saved zone id 21001. Count=6456, AddedZeros=24
# Saved zone id 21005. Count=6456, AddedZeros=24
# Saved zone id 21904. Count=6456, AddedZeros=24
# Saved zone id 23003. Count=6456, AddedZeros=24
# Saved zone id 23005. Count=6456, AddedZeros=24
# Saved zone id 25001. Count=6456, AddedZeros=24
# Saved zone id 25304. Count=6456, AddedZeros=24
# Saved zone id 25901. Count=6456, AddedZeros=24
# Saved zone id 25905. Count=6456, AddedZeros=24
# Saved zone id 25908. Count=6456, AddedZeros=24
# Saved zone id 26525. Count=6456, AddedZeros=24
# Saved zone id 37011. Count=6456, AddedZeros=24
# Saved zone id 37014. Count=6456, AddedZeros=24

# %%
plt.plot(ds[:(7*24)])
plt.plot(ss[:(7*24)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3z/pggbcw7949507j0lbw1gjngc0000gn/T/ipykernel_97482/1809728725.py in <module>
# ----> 1 plt.plot(ds[:(7*24)])
#       2 plt.plot(ss[:(7*24)])
#
# NameError: name 'ds' is not defined
