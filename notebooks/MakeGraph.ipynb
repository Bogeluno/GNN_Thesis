# %%
import pandas as pd
import networkx as nx
import numpy as np

# %%
df = pd.read_csv('data/processed/Vacancy.csv', index_col=0)

df

# %%
# Out:
#         Unnamed: 0                car            park_time  \
# 0                0  WBY1Z21070V307929  2017-08-01 12:49:44
# 1                1  WBY1Z21070V307929  2017-08-28 19:54:45
# 2                2  WBY1Z21070V307929  2017-08-28 21:03:40
# 3                3  WBY1Z21070V307929  2017-08-29 17:05:55
# 4                4  WBY1Z21070V307929  2017-08-29 22:36:35
# ...            ...                ...                  ...
# 366015      366015  WBY1Z21010V307893  2018-05-08 12:55:32
# 366016      366016  WBY1Z21010V307893  2018-05-08 13:19:22
# 366017      366017  WBY1Z21010V307893  2018-05-08 14:52:59
# 366018      366018  WBY1Z21010V307893  2018-05-08 15:19:43
# 366019      366019  WBY1Z21010V307893  2018-05-08 18:31:27
#
#            reservation_time  time_to_reservation  time_to_start  \
# 0       2017-08-28 19:12:32           654.380000     654.463333
# 1       2017-08-28 20:45:33             0.846667       0.880000
# ...
